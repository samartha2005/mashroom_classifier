# %%
# !pip install path/to/database_connect-0.1-py3-none-any.whl
# Out:
# Processing c:\machine_learning_project\mashroom_classifier\upload_to_db\mongo_db_upload_data\path\to\database_connect-0.1-py3-none-any.whl
# WARNING: Requirement 'path/to/database_connect-0.1-py3-none-any.whl' looks like a filename, but the file does not exist
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Machine_Learning_Project\\mashroom_classifier\\upload_to_db\\mongo_db_upload_data\\path\\to\\database_connect-0.1-py3-none-any.whl'

# %%
pip install pymongo
# Out:
# ...
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/680.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/680.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/680.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/680.4 kB ? eta -:--:--
#    - ------------------------------------- 30.7/680.4 kB 131.3 kB/s eta 0:00:05
#    - ------------------------------------- 30.7/680.4 kB 131.3 kB/s eta 0:00:05
#    - ------------------------------------- 30.7/680.4 kB 131.3 kB/s eta 0:00:05
#    -- ------------------------------------ 41.0/680.4 kB 103.4 kB/s eta 0:00:07
#    -- ------------------------------------ 41.0/680.4 kB 103.4 kB/s eta 0:00:07
# ...

# %%
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://samartha:12345@mashroom.kk0pf.mongodb.net/?retryWrites=true&w=majority&appName=mashroom")
db = client["mashroom"]
collection = db["mashroom"]

# %%
document = collection.find_one() 
print(document)
# Out:
# None

# %%
import os
from database_Connect.databases.mongodb import MongoIO as mongo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 2
#       1 import os
# ----> 2 from database_Connect.databases.mongodb import MongoIO as mongo
#
# ModuleNotFoundError: No module named 'database_Connect'

# %%
import database_connect.databases.mongodb
print(dir(database_connect.databases.mongodb))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import database_connect.databases.mongodb
#       2 print(dir(database_connect.databases.mongodb))
#
# ModuleNotFoundError: No module named 'database_connect'
